# %% [markdown]
# <a href="https://colab.research.google.com/github/ETorresSacha/Analisis-de-datos/blob/main/AD_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # series

# %%
numeros = [3,4,5,6,7]
serie = pd.Series(numeros)
serie, type(serie)
# Out:
# (0    3
#  1    4
#  2    5
#  3    6
#  4    7
#  dtype: int64,
#  pandas.core.series.Series)

# %%
data = {
    "Nombre":['Ana','Juan','Pedro','María','Luis'],
    "Edad":[22,25,28,23,20],
    "Ciudad":['Barcelona','Madrid','Valencia','Sevilla','Bilboa']}
data,type(data)
# Out:
# ({'Nombre': ['Ana', 'Juan', 'Pedro', 'María', 'Luis'],
#   'Edad': [22, 25, 28, 23, 20],
#   'Ciudad': ['Barcelona', 'Madrid', 'Valencia', 'Sevilla', 'Bilboa']},
#  dict)

# %%
# Generar un dataframe a partir de un diccionario
df = pd.DataFrame(data=data)
df
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    22  Barcelona
# 1   Juan    25     Madrid
# 2  Pedro    28   Valencia
# 3  María    23    Sevilla
# 4   Luis    20     Bilboa
